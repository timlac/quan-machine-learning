# %%
import pandas as pd

# %%
path = "../files/tests/out/csv_concat_test.csv"
df = pd.read_csv(path)

# %%
df[df['mix'] == True]
# Out:
#       Unnamed: 0  frame  face_id  timestamp  confidence  success  gaze_0_x  \
# 706            0      1        0       0.00        0.98        1  0.037525
# 707            1      2        0       0.02        0.98        1  0.035051
# 708            2      3        0       0.04        0.98        1  0.040302
# 709            3      4        0       0.06        0.98        1  0.040535
# 710            4      5        0       0.08        0.98        1  0.041836
# ...          ...    ...      ...        ...         ...      ...       ...
# 2600         540    541        0      10.80        0.98        1  0.092694
# 2601         541    542        0      10.82        0.98        1  0.098033
# 2602         542    543        0      10.84        0.98        1  0.099049
# 2603         543    544        0      10.86        0.98        1  0.095215
# 2604         544    545        0      10.88        0.98        1  0.091627
#
# ...

# %%
df
# Out:
#       Unnamed: 0  frame  face_id  timestamp  confidence  success  gaze_0_x  \
# 0              0      1        0       0.00        0.98        1  0.041166
# 1              1      2        0       0.02        0.98        1  0.051925
# 2              2      3        0       0.04        0.98        1  0.050509
# 3              3      4        0       0.06        0.98        1  0.051062
# 4              4      5        0       0.08        0.98        1  0.048621
# ...          ...    ...      ...        ...         ...      ...       ...
# 2787         182    183        0       3.64        0.98        1  0.013828
# 2788         183    184        0       3.66        0.98        1  0.000961
# 2789         184    185        0       3.68        0.98        1 -0.021014
# 2790         185    186        0       3.70        0.98        1 -0.049001
# 2791         186    187        0       3.72        0.98        1 -0.061786
#
# ...

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
"Filename {} contains error marker, skipping file".format("filename")
# Out:
# 'Filename filename contains error marker, skipping file'
