# %%
import os
import sys
import boto3
import pickle

import numpy as np
from sklearn.svm import SVC

from sagemaker.sklearn.estimator import SKLearn
from sklearn.model_selection import cross_validate

# %%
os.chdir('/root/emotional-recognition/notebooks/functionals/supervised_learning/')

# %%
pwd
# Out:
# '/root/emotional-recognition/notebooks/functionals/supervised_learning'

# %%
module_path = os.path.abspath(os.path.join('../../../'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from label_transforms import *

# %%
from s3fs.core import S3FileSystem
s3 = S3FileSystem()
from sagemaker import get_execution_role

role = get_execution_role()
bucket='files-and-examples-01'
train_file = 'datasets/su_dataset/video_data_functionals_A74.npz'

train_path = s3.open('s3://{}/{}'.format(bucket, train_file))

f = np.load(train_path)

x = f['x']
y = f['y']

# %%
train_uri = f"s3://{bucket}/{train_file}"

# %%
train_uri
# Out:
# 's3://files-and-examples-01/datasets/su_dataset/video_data_functionals_A74.npz'

# %%
x.shape
# Out:
# (341, 85)

# %%
y.shape
# Out:
# (341,)

# %%
train_instance_type = "ml.m5.large"

inputs = {
    "train": train_uri
}

# %%
inputs
# Out:
# {'train': 's3://files-and-examples-01/datasets/su_dataset/video_data_functionals_A74.npz'}

# %%
estimator_parameters = {
    "entry_point": "svm_param_search.py",
    "source_dir": "scripts",
    "framework_version": "0.23-1",
    "py_version": "py3",
    "instance_type": train_instance_type,
    "instance_count": 1,
    "role": role,
    "base_job_name": "svm-param-search",
}

estimator = SKLearn(**estimator_parameters)

# %%
estimator.fit(inputs)
# Out:
# 2022-11-02 15:51:51 Starting - Starting the training job...
# 2022-11-02 15:52:17 Starting - Preparing the instances for trainingProfilerReport-1667404311: InProgress
# .........
# 2022-11-02 15:53:37 Downloading - Downloading input data...
# 2022-11-02 15:54:18 Training - Downloading the training image......
# 2022-11-02 15:55:18 Training - Training image download completed. Training in progress.2022-11-02 15:55:02,425 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2022-11-02 15:55:02,433 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-11-02 15:55:02,468 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2022-11-02 15:55:03,084 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-11-02 15:55:03,102 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-11-02 15:55:03,133 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-11-02 15:55:03,150 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {},
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "svm-param-search-2022-11-02-15-51-51-300",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-eu-west-1-061749825266/svm-param-search-2022-11-02-15-51-51-300/source/sourcedir.tar.gz",
#     "module_name": "svm_param_search",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.large",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.large",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "svm_param_search.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={}
# SM_USER_ENTRY_POINT=svm_param_search.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=svm_param_search
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-eu-west-1-061749825266/svm-param-search-2022-11-02-15-51-51-300/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"svm-param-search-2022-11-02-15-51-51-300","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-eu-west-1-061749825266/svm-param-search-2022-11-02-15-51-51-300/source/sourcedir.tar.gz","module_name":"svm_param_search","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0"},"user_entry_point":"svm_param_search.py"}
# SM_USER_ARGS=[]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
# Invoking script with the following command:
# /miniconda3/bin/python svm_param_search.py
# printing args
# Namespace(model_dir='/opt/ml/model', train='/opt/ml/input/data/train')
# printing args.train:
# /opt/ml/input/data/train
# done printing args train
# ['video_data_functionals_A74.npz']
# x: (341, 85) y: (341,)
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=rbf ...............
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=rbf ...............
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=rbf, score=0.058, total=   0.1s
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    2.0s
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=rbf, score=0.118, total=   0.1s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.0s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=rbf ...............
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=rbf ...............
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=rbf, score=0.074, total=   0.1s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    2.1s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=rbf ...............
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=rbf, score=0.074, total=   0.1s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    2.2s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=linear ............
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=linear, score=0.217, total=   0.0s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    2.2s
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=rbf, score=0.103, total=   0.1s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    2.2s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=linear ............
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=linear ............
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=linear, score=0.074, total=   0.1s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    2.3s
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=linear, score=0.118, total=   0.1s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    2.3s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=linear ............
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=linear ............
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=linear, score=0.265, total=   0.1s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.4s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=poly ..............
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=linear, score=0.191, total=   0.1s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    2.4s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=poly ..............
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=poly, score=0.088, total=   0.1s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    2.5s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=poly ..............
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=poly, score=0.188, total=   0.1s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    2.5s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=poly ..............
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=poly, score=0.103, total=   0.1s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    2.5s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=poly ..............
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=poly, score=0.118, total=   0.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    2.6s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=sigmoid ...........
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=poly, score=0.162, total=   0.1s
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    2.6s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=sigmoid ...........
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=sigmoid, score=0.014, total=   0.0s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    2.6s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=sigmoid ...........
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=sigmoid, score=0.029, total=   0.0s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    2.6s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=sigmoid ...........
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=sigmoid, score=0.029, total=   0.0s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    2.7s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=sigmoid ...........
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=sigmoid, score=0.044, total=   0.0s
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=sigmoid, score=0.029, total=   0.0s
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1894s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:    2.7s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf .............
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf .............
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.029, total=   0.0s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    2.7s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf .............
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.118, total=   0.1s
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:    2.8s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf .............
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.044, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf .............
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.221, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=linear ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.147, total=   0.1s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1545s.) Setting batch_size=4.
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=linear, score=0.217, total=   0.0s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    2.9s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=linear ..........
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=linear ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=linear, score=0.118, total=   0.1s[CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=linear, score=0.191, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=linear ..........
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=linear ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=linear, score=0.074, total=   0.1s
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    3.0s
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=linear, score=0.265, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=poly ............[Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    3.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=poly ............
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=poly, score=0.188, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=poly ............
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=poly, score=0.191, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid .........
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=poly, score=0.088, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=poly ............
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid, score=0.014, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid .........
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=poly, score=0.118, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=poly ............
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid, score=0.029, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid .........
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=poly, score=0.147, total=   0.1s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    3.4s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid .........
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid, score=0.000, total=   0.1s
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:    3.5s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid, score=0.000, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid .........
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.074, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.103, total=   0.1s[CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid, score=0.044, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.029, total=   0.1s[CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.176, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=linear .........
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=linear, score=0.217, total=   0.1s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    3.8s
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.147, total=   0.1s
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:    3.9s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=poly ...........
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=linear .........
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=poly, score=0.043, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=poly ...........
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=linear, score=0.118, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=linear .........
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=poly, score=0.147, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=poly ...........
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=linear, score=0.074, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=linear .........
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=poly, score=0.088, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=poly ...........
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=linear, score=0.191, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=linear .........
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=poly, score=0.118, total=   0.0s
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:    4.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=poly ...........
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=linear, score=0.265, total=   0.0s
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:    4.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid ........
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=poly, score=0.132, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid ........
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid, score=0.162, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid ........
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid, score=0.014, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid ........
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid, score=0.176, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid, score=0.132, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid ........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.014, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid, score=0.029, total=   0.1s
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:    4.2s
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.118, total=   0.0s
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:    4.2s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=linear ........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=linear, score=0.118, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=linear ........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.103, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=linear, score=0.074, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=linear ........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.118, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=linear, score=0.191, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=linear ........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.147, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=linear ........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=linear, score=0.265, total=   0.0s
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:    4.5s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=poly ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=linear, score=0.217, total=   0.0s
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:    4.5s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=poly ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=poly, score=0.043, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=poly ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=poly, score=0.132, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid .......
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=poly, score=0.147, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=poly ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid, score=0.014, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid .......
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=poly, score=0.088, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=poly ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid, score=0.132, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid .......
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=poly, score=0.118, total=   0.0s
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:    4.7s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid .......
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid, score=0.103, total=   0.1s
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:    4.7s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid, score=0.118, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid .......
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.103, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid, score=0.147, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.118, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.014, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.147, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=linear .......
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.118, total=   0.0s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:    4.9s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=linear .......
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=linear, score=0.217, total=   0.0s
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:    4.9s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=poly .........
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=linear, score=0.118, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=linear .......
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=poly, score=0.043, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=poly .........
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=linear, score=0.074, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=linear .......
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=poly, score=0.147, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=poly .........
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=linear, score=0.191, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=linear .......
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=poly, score=0.088, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=poly .........
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=linear, score=0.265, total=   0.1s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:    5.2s
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=poly, score=0.118, total=   0.1s
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed:    5.2s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=poly .........
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=sigmoid ......
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=poly, score=0.132, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=sigmoid ......
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=sigmoid, score=0.118, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=sigmoid ......
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=sigmoid, score=0.014, total=   0.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=sigmoid ......
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=sigmoid, score=0.147, total=   0.0s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=rbf .................
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=rbf, score=0.087, total=   0.0s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=rbf .................
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=sigmoid, score=0.118, total=   0.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=sigmoid ......
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=rbf, score=0.074, total=   0.1s
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:    5.4s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=rbf .................
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=sigmoid, score=0.103, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed:    5.5s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=linear ..............
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=rbf, score=0.015, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=rbf .................
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=linear, score=0.103, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=linear ..............
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=rbf, score=0.029, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=rbf .................
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=linear, score=0.118, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=linear ..............
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=rbf, score=0.074, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=linear ..............
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=linear, score=0.103, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=linear ..............
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=linear, score=0.188, total=   0.0s
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:    5.8s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=poly ................
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=linear, score=0.191, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed:    5.8s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=poly ................
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=poly, score=0.188, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=poly ................
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=poly, score=0.162, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=sigmoid .............
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=sigmoid, score=0.014, total=   0.0s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=sigmoid .............
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=poly, score=0.088, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=poly ................
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=sigmoid, score=0.029, total=   0.0s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=sigmoid .............
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=poly, score=0.103, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=poly ................
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=sigmoid, score=0.029, total=   0.0s
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:    6.0s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=sigmoid .............
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=sigmoid, score=0.029, total=   0.0s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=sigmoid .............
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=poly, score=0.118, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed:    6.0s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=rbf ...............
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=sigmoid, score=0.029, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=rbf ...............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.074, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=rbf ...............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.174, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=rbf ...............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.147, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=rbf ...............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.147, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:    6.3s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=linear ............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.191, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=linear ............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=linear, score=0.103, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=linear ............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=linear, score=0.188, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed:    6.4s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=poly ..............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=linear, score=0.118, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=linear ............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=poly, score=0.188, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=poly ..............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=linear, score=0.103, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=linear ............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=poly, score=0.088, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=poly ..............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=linear, score=0.191, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    6.6s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=poly ..............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=poly, score=0.103, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=poly ..............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=poly, score=0.162, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid ...........
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=poly, score=0.118, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed:    6.7s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid ...........
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid, score=0.014, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid ...........
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid, score=0.000, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid ...........
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid, score=0.029, total=   0.0s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid ...........
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid, score=0.044, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=rbf ..............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid, score=0.000, total=   0.0s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:    6.9s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=rbf ..............
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.159, total=   0.0s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=rbf ..............
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.074, total=   0.0s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=rbf ..............
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.147, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 142 tasks      | elapsed:    6.9s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=linear ...........
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.103, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=rbf ..............
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=linear, score=0.103, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=linear ...........
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.176, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=linear ...........
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=linear, score=0.118, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=linear ...........
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=linear, score=0.188, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:    7.2s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=poly .............
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=linear, score=0.103, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=linear ...........
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=poly, score=0.145, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=poly .............
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=poly, score=0.132, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=poly .............
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=linear, score=0.191, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 150 tasks      | elapsed:    7.3s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=poly .............
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=poly, score=0.103, total=   0.1s
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=poly, score=0.088, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=poly .............
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=sigmoid ..........
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=poly, score=0.118, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:    7.5s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=sigmoid ..........
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=sigmoid, score=0.188, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=sigmoid ..........
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=sigmoid, score=0.162, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=sigmoid ..........
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=sigmoid, score=0.132, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=sigmoid ..........
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=sigmoid, score=0.176, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=sigmoid, score=0.029, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:    7.7s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.174, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.088, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.118, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 162 tasks      | elapsed:    7.8s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=linear ..........
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.118, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=linear, score=0.103, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=linear ..........
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.147, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=linear ..........
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=linear, score=0.118, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=linear ..........
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=linear, score=0.188, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 166 tasks      | elapsed:    8.0s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=poly ............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=linear, score=0.103, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=linear ..........
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=poly, score=0.145, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=poly ............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=linear, score=0.191, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 170 tasks      | elapsed:    8.2s
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=poly, score=0.147, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=poly ............
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=poly ............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=poly, score=0.132, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=sigmoid .........
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=poly, score=0.088, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=poly ............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=poly, score=0.118, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 174 tasks      | elapsed:    8.4s
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=sigmoid, score=0.188, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=sigmoid .........
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=sigmoid .........
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=sigmoid, score=0.118, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=sigmoid .........
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=sigmoid, score=0.132, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=sigmoid .........
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=sigmoid, score=0.147, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=sigmoid, score=0.088, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 178 tasks      | elapsed:    8.6s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.188, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.088, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.118, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 182 tasks      | elapsed:    8.8s
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.118, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=linear .........
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=linear, score=0.103, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=linear .........
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.147, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=linear .........
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=linear, score=0.118, total=   0.0s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=linear .........
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=linear, score=0.103, total=   0.0s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=linear .........
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=linear, score=0.188, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 186 tasks      | elapsed:    8.9s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=poly ...........
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=linear, score=0.191, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 190 tasks      | elapsed:    9.0s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=poly ...........
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=poly, score=0.145, total=   0.1s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=poly ...........
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=poly, score=0.132, total=   0.0s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=sigmoid ........
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=poly, score=0.147, total=   0.0s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=poly ...........
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=sigmoid, score=0.188, total=   0.0s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=sigmoid ........
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=poly, score=0.088, total=   0.0s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=poly ...........
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=sigmoid, score=0.118, total=   0.0s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=sigmoid ........
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=poly, score=0.118, total=   0.0s
# [Parallel(n_jobs=-1)]: Done 194 tasks      | elapsed:    9.1s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=sigmoid ........
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=sigmoid, score=0.088, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 198 tasks      | elapsed:    9.2s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=rbf ................
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=sigmoid, score=0.118, total=   0.0s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=sigmoid ........
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=rbf, score=0.029, total=   0.1s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=rbf ................
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=sigmoid, score=0.147, total=   0.0s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=rbf ................
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=rbf, score=0.029, total=   0.0s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=rbf ................
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=rbf, score=0.087, total=   0.1s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=rbf ................
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=rbf, score=0.074, total=   0.0s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=linear .............
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=rbf, score=0.044, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 202 tasks      | elapsed:    9.4s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=linear .............
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=linear, score=0.203, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 206 tasks      | elapsed:    9.4s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=poly ...............
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=linear, score=0.088, total=   0.0s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=linear .............
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=poly, score=0.188, total=   0.1s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=poly ...............
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=linear, score=0.118, total=   0.1s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=linear .............
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=poly, score=0.088, total=   0.0s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=poly ...............
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=linear, score=0.088, total=   0.1s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=linear .............
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=poly, score=0.103, total=   0.0s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=poly ...............
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=linear, score=0.176, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 210 tasks      | elapsed:    9.6s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=poly ...............
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=poly, score=0.118, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 214 tasks      | elapsed:    9.6s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=sigmoid ............
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=sigmoid, score=0.029, total=   0.0s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=sigmoid ............
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=poly, score=0.162, total=   0.1s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=sigmoid ............
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=sigmoid, score=0.029, total=   0.0s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=rbf ..............
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=sigmoid, score=0.014, total=   0.1s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=sigmoid ............
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=sigmoid, score=0.029, total=   0.1s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=sigmoid ............
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.116, total=   0.1s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=rbf ..............
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=sigmoid, score=0.029, total=   0.0s
# [Parallel(n_jobs=-1)]: Done 218 tasks      | elapsed:    9.8s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=rbf ..............
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.103, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 222 tasks      | elapsed:    9.8s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=linear ...........
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.088, total=   0.1s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=rbf ..............
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=linear, score=0.088, total=   0.1s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=linear ...........
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.147, total=   0.1s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=rbf ..............
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=linear, score=0.118, total=   0.1s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=linear ...........
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.162, total=   0.0s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=linear ...........
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=linear, score=0.088, total=   0.1s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=linear ...........
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=linear, score=0.203, total=   0.0s
# [Parallel(n_jobs=-1)]: Done 226 tasks      | elapsed:   10.0s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=poly .............
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=linear, score=0.176, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 230 tasks      | elapsed:   10.1s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=poly .............
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=poly, score=0.188, total=   0.1s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=poly .............
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=poly, score=0.162, total=   0.1s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid ..........
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=poly, score=0.088, total=   0.1s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=poly .............
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid, score=0.000, total=   0.1s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid ..........
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=poly, score=0.103, total=   0.1s
# ...
# [CV] C=1000, class_weight=balanced, gamma=1, kernel=sigmoid ..........
# [CV]  C=1000, class_weight=balanced, gamma=1, kernel=poly, score=0.088, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=1, kernel=poly .............
# [CV]  C=1000, class_weight=balanced, gamma=1, kernel=sigmoid, score=0.029, total=   0.0s
# [CV] C=1000, class_weight=balanced, gamma=1, kernel=sigmoid ..........
# [CV]  C=1000, class_weight=balanced, gamma=1, kernel=poly, score=0.103, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=1, kernel=poly .............
# [CV]  C=1000, class_weight=balanced, gamma=1, kernel=sigmoid, score=0.029, total=   0.0s
# [CV] C=1000, class_weight=balanced, gamma=1, kernel=sigmoid ..........
# [CV]  C=1000, class_weight=balanced, gamma=1, kernel=sigmoid, score=0.029, total=   0.0s
# [Parallel(n_jobs=-1)]: Done 414 tasks      | elapsed:   17.8s
# [CV] C=1000, class_weight=balanced, gamma=1, kernel=sigmoid ..........
# [CV]  C=1000, class_weight=balanced, gamma=1, kernel=poly, score=0.118, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:   17.8s
# [CV] C=1000, class_weight=balanced, gamma=0.1, kernel=rbf ............
# [CV]  C=1000, class_weight=balanced, gamma=1, kernel=sigmoid, score=0.029, total=   0.0s
# [CV] C=1000, class_weight=balanced, gamma=1, kernel=sigmoid ..........
# [CV]  C=1000, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.088, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.1, kernel=rbf ............
# [CV]  C=1000, class_weight=balanced, gamma=1, kernel=sigmoid, score=0.029, total=   0.0s
# [CV] C=1000, class_weight=balanced, gamma=0.1, kernel=rbf ............
# [CV]  C=1000, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.147, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.1, kernel=rbf ............
# [CV]  C=1000, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.116, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.1, kernel=rbf ............
# [CV]  C=1000, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.162, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.1, kernel=linear .........
# [CV]  C=1000, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.103, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 422 tasks      | elapsed:   18.1s
# [CV] C=1000, class_weight=balanced, gamma=0.1, kernel=linear .........
# [CV]  C=1000, class_weight=balanced, gamma=0.1, kernel=linear, score=0.203, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:   18.1s
# [CV] C=1000, class_weight=balanced, gamma=0.1, kernel=poly ...........
# [CV]  C=1000, class_weight=balanced, gamma=0.1, kernel=poly, score=0.188, total=   0.0s
# [CV] C=1000, class_weight=balanced, gamma=0.1, kernel=poly ...........
# [CV]  C=1000, class_weight=balanced, gamma=0.1, kernel=linear, score=0.088, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.1, kernel=linear .........
# [CV]  C=1000, class_weight=balanced, gamma=0.1, kernel=poly, score=0.088, total=   0.0s
# [CV] C=1000, class_weight=balanced, gamma=0.1, kernel=poly ...........
# [CV]  C=1000, class_weight=balanced, gamma=0.1, kernel=linear, score=0.118, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.1, kernel=linear .........
# [CV]  C=1000, class_weight=balanced, gamma=0.1, kernel=poly, score=0.103, total=   0.0s
# [CV] C=1000, class_weight=balanced, gamma=0.1, kernel=poly ...........
# [CV]  C=1000, class_weight=balanced, gamma=0.1, kernel=poly, score=0.118, total=   0.0s
# [Parallel(n_jobs=-1)]: Done 430 tasks      | elapsed:   18.3s
# [CV] C=1000, class_weight=balanced, gamma=0.1, kernel=poly ...........
# [CV]  C=1000, class_weight=balanced, gamma=0.1, kernel=linear, score=0.088, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.1, kernel=linear .........
# [CV]  C=1000, class_weight=balanced, gamma=0.1, kernel=poly, score=0.162, total=   0.0s
# [CV] C=1000, class_weight=balanced, gamma=0.1, kernel=sigmoid ........
# [CV]  C=1000, class_weight=balanced, gamma=0.1, kernel=linear, score=0.176, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:   18.3s
# [CV] C=1000, class_weight=balanced, gamma=0.1, kernel=sigmoid ........
# [CV]  C=1000, class_weight=balanced, gamma=0.1, kernel=sigmoid, score=0.029, total=   0.0s
# [CV] C=1000, class_weight=balanced, gamma=0.1, kernel=sigmoid ........
# [CV]  C=1000, class_weight=balanced, gamma=0.1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1000, class_weight=balanced, gamma=0.1, kernel=sigmoid ........
# [CV]  C=1000, class_weight=balanced, gamma=0.1, kernel=sigmoid, score=0.029, total=   0.0s
# [CV] C=1000, class_weight=balanced, gamma=0.1, kernel=sigmoid ........
# [CV]  C=1000, class_weight=balanced, gamma=0.1, kernel=sigmoid, score=0.029, total=   0.0s
# [CV] C=1000, class_weight=balanced, gamma=0.01, kernel=rbf ...........
# [CV]  C=1000, class_weight=balanced, gamma=0.1, kernel=sigmoid, score=0.000, total=   0.0s
# [Parallel(n_jobs=-1)]: Done 438 tasks      | elapsed:   18.4s
# [CV] C=1000, class_weight=balanced, gamma=0.01, kernel=rbf ...........
# [CV]  C=1000, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.130, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.01, kernel=rbf ...........
# [CV]  C=1000, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.074, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.01, kernel=rbf ...........
# [CV]  C=1000, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.088, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:   18.5s
# [CV] C=1000, class_weight=balanced, gamma=0.01, kernel=linear ........
# [CV]  C=1000, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.147, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.01, kernel=rbf ...........
# [CV]  C=1000, class_weight=balanced, gamma=0.01, kernel=linear, score=0.088, total=   0.0s
# [CV] C=1000, class_weight=balanced, gamma=0.01, kernel=linear ........
# [CV]  C=1000, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.221, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.01, kernel=linear ........
# [CV]  C=1000, class_weight=balanced, gamma=0.01, kernel=linear, score=0.118, total=   0.0s
# [CV] C=1000, class_weight=balanced, gamma=0.01, kernel=linear ........
# [CV]  C=1000, class_weight=balanced, gamma=0.01, kernel=linear, score=0.203, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 446 tasks      | elapsed:   18.7s
# [CV] C=1000, class_weight=balanced, gamma=0.01, kernel=poly ..........
# [CV]  C=1000, class_weight=balanced, gamma=0.01, kernel=linear, score=0.088, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.01, kernel=linear ........
# [CV]  C=1000, class_weight=balanced, gamma=0.01, kernel=poly, score=0.188, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.01, kernel=poly ..........
# [CV]  C=1000, class_weight=balanced, gamma=0.01, kernel=linear, score=0.176, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 450 tasks      | elapsed:   18.8s
# [CV] C=1000, class_weight=balanced, gamma=0.01, kernel=poly ..........
# [CV]  C=1000, class_weight=balanced, gamma=0.01, kernel=poly, score=0.088, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.01, kernel=poly ..........
# [CV]  C=1000, class_weight=balanced, gamma=0.01, kernel=poly, score=0.162, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.01, kernel=sigmoid .......
# [CV]  C=1000, class_weight=balanced, gamma=0.01, kernel=poly, score=0.103, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.01, kernel=poly ..........
# [CV]  C=1000, class_weight=balanced, gamma=0.01, kernel=sigmoid, score=0.130, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.01, kernel=sigmoid .......
# [CV]  C=1000, class_weight=balanced, gamma=0.01, kernel=poly, score=0.118, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 454 tasks      | elapsed:   19.1s
# [CV] C=1000, class_weight=balanced, gamma=0.01, kernel=sigmoid .......
# [CV]  C=1000, class_weight=balanced, gamma=0.01, kernel=sigmoid, score=0.118, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.01, kernel=sigmoid .......
# [CV]  C=1000, class_weight=balanced, gamma=0.01, kernel=sigmoid, score=0.088, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.01, kernel=sigmoid .......
# [CV]  C=1000, class_weight=balanced, gamma=0.01, kernel=sigmoid, score=0.015, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 458 tasks      | elapsed:   19.3s
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=rbf ..........
# [CV]  C=1000, class_weight=balanced, gamma=0.01, kernel=sigmoid, score=0.118, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=rbf ..........
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.118, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=rbf ..........
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.203, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=rbf ..........
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.103, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=rbf ..........
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.088, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 462 tasks      | elapsed:   19.6s
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=linear .......
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.206, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=linear .......
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=linear, score=0.088, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=linear .......
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=linear, score=0.203, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 466 tasks      | elapsed:   19.8s
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=poly .........
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=linear, score=0.118, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=linear .......
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=poly, score=0.174, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=poly .........
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=linear, score=0.088, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=linear .......
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=poly, score=0.132, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=poly .........
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=poly, score=0.088, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=poly .........
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=linear, score=0.176, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 470 tasks      | elapsed:   20.1s
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=poly .........
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=poly, score=0.118, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 474 tasks      | elapsed:   20.1s
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=sigmoid ......
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=poly, score=0.132, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=sigmoid ......
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=sigmoid, score=0.103, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=sigmoid ......
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=sigmoid, score=0.174, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=sigmoid ......
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=sigmoid, score=0.191, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf .........
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=sigmoid, score=0.103, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=sigmoid ......
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.217, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf .........
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=sigmoid, score=0.118, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 478 tasks      | elapsed:   20.5s
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf .........
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.103, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 482 tasks      | elapsed:   20.6s
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=linear ......
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.074, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf .........
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=linear, score=0.088, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=linear ......
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.206, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf .........
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=linear, score=0.118, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=linear ......
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.191, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=linear ......
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=linear, score=0.088, total=   0.1s
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=linear ......
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=linear, score=0.203, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 486 tasks      | elapsed:   20.9s
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=poly ........
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=poly, score=0.029, total=   0.0s
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=poly ........
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=linear, score=0.176, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 490 tasks      | elapsed:   21.0s
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=poly ........
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=poly, score=0.147, total=   0.0s
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=poly ........
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=poly, score=0.132, total=   0.0s
# [Parallel(n_jobs=-1)]: Done 491 tasks      | elapsed:   21.0s
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=sigmoid .....
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=poly, score=0.088, total=   0.0s
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=poly ........
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=sigmoid, score=0.217, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 492 tasks      | elapsed:   21.1s
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=sigmoid .....
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=poly, score=0.118, total=   0.0s
# [Parallel(n_jobs=-1)]: Done 496 tasks      | elapsed:   21.1s
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=sigmoid .....
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=sigmoid, score=0.118, total=   0.0s
# [Parallel(n_jobs=-1)]: Done 497 tasks      | elapsed:   21.1s
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=sigmoid .....
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=sigmoid, score=0.074, total=   0.0s
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=sigmoid .....
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=sigmoid, score=0.191, total=   0.0s
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=sigmoid, score=0.265, total=   0.1s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   21.2s finished
# 2022-11-02 15:55:26,086 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2022-11-02 15:55:50 Uploading - Uploading generated training model
# 2022-11-02 15:55:50 Completed - Training job completed
# Training seconds: 142
# Billable seconds: 142

# %%
# !aws s3 cp {estimator.model_data} ./model/model.tar.gz
# Out:
# download: s3://sagemaker-eu-west-1-061749825266/svm-param-search-2022-11-02-15-51-51-300/output/model.tar.gz to model/model.tar.gz

# %%
# !tar -xvzf ./model/model.tar.gz -C ./model
# Out:
# model.pickle

# %%
loaded_model = pickle.load(open("model/model.pickle", 'rb'))
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator SVC from version 0.23.2 when using version 0.22.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator GridSearchCV from version 0.23.2 when using version 0.22.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
def evaluate_scores(X, y, clf, scoring_method):
    # get scores
    scores = cross_validate(X=X, y=y,
                            estimator           = clf,
                            scoring             = [scoring_method],
                            verbose             = 1,
                            n_jobs              = -1,
                            return_train_score  = True                        
                           )
    
    print('printing {} measures'.format(scoring_method))
    print('avg (train):', np.mean(scores['train_{}'.format(scoring_method)]))
    print('std (train):', np.std(scores['train_{}'.format(scoring_method)]))
    print('avg (validation):', np.mean(scores['test_{}'.format(scoring_method)]))
    print('std (validation):', np.std(scores['test_{}'.format(scoring_method)]))

# %%
svc = loaded_model.best_estimator_

# %%
evaluate_scores(x, y, svc, "accuracy")
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# printing accuracy measures
# avg (train): 0.5102644904115492
# std (train): 0.030418571777857506
# avg (validation): 0.1758312020460358
# std (validation): 0.0666594983968966
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    1.5s finished

# %%
svc = SVC(**loaded_model.best_params_)

# %%
evaluate_scores(x, y, svc, "accuracy")
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# printing accuracy measures
# avg (train): 0.5102644904115492
# std (train): 0.030418571777857506
# avg (validation): 0.1758312020460358
# std (validation): 0.0666594983968966
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.5s finished

# %% [markdown]
# # Testing on A220 dataset

# %%
from s3fs.core import S3FileSystem
s3 = S3FileSystem()
from sagemaker import get_execution_role

role = get_execution_role()
bucket='files-and-examples-01'
train_file = 'datasets/su_dataset/video_data_functionals_A220.npz'

train_path = s3.open('s3://{}/{}'.format(bucket, train_file))

f = np.load(train_path)

x = f['x']
y = f['y']

# %%
train_uri = f"s3://{bucket}/{train_file}"

# %%
train_uri
# Out:
# 's3://files-and-examples-01/datasets/su_dataset/video_data_functionals_A220.npz'

# %%
train_instance_type = "ml.m5.large"

inputs = {
    "train": train_uri
}

# %%
estimator_parameters = {
    "entry_point": "svm_param_search.py",
    "source_dir": "scripts",
    "framework_version": "0.23-1",
    "py_version": "py3",
    "instance_type": train_instance_type,
    "instance_count": 1,
    "role": role,
    "base_job_name": "svm-param-search",
}

estimator = SKLearn(**estimator_parameters)

# %%
estimator.fit(inputs, logs="None")
# Out:
# 2022-11-02 16:31:24 Starting - Starting the training job..........
# 2022-11-02 16:32:18 Starting - Preparing the instances for training..............
# 2022-11-02 16:33:33 Downloading - Downloading input data.......
# 2022-11-02 16:34:13 Training - Downloading the training image.........
# 2022-11-02 16:35:03 Training - Training image download completed. Training in progress......
# 2022-11-02 16:35:34 Uploading - Uploading generated training model..
# 2022-11-02 16:35:50 Completed - Training job completed

# %%
# !aws s3 cp {estimator.model_data} ./model/model.tar.gz
# !tar -xvzf ./model/model.tar.gz -C ./model
# Out:
# download: s3://sagemaker-eu-west-1-061749825266/svm-param-search-2022-11-02-16-16-09-460/output/model.tar.gz to model/model.tar.gz
# model.pickle

# %%
loaded_model = pickle.load(open("model/model.pickle", 'rb'))
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator SVC from version 0.23.2 when using version 0.22.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator GridSearchCV from version 0.23.2 when using version 0.22.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
svc = SVC(**loaded_model.best_params_)
evaluate_scores(x, y, svc, "accuracy")
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# printing accuracy measures
# avg (train): 0.7187324903460286
# std (train): 0.024943040369078975
# avg (validation): 0.40321931589537224
# std (validation): 0.08675192111740986
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    1.2s finished
