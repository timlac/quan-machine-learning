# %%
import os
import sys
from glob import glob
from pathlib import Path
from tqdm import tqdm
from dotenv import load_dotenv

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import sklearn as sk
import pickle
import copy

# %%
load_dotenv()
output_path = os.getenv("VIDEO_OUT")
# Global configuration path
glob_conf_path = '../../global_config.py'

# %%
exec(open(glob_conf_path).read())

# %%
df = pd.read_csv(output_path + 'video_data_time_series.csv')

# %%
df
# Out:
#                filename  frame video_id  emotion_1_id  AU01_r    AU02_r  \
# 0      A227_neg_sur_v_4      1     A227            11   0.000  0.000000
# 1      A227_neg_sur_v_4      2     A227            11   0.000  0.000000
# 2      A227_neg_sur_v_4      3     A227            11   0.000  0.000000
# 3      A227_neg_sur_v_4      4     A227            11   0.000  0.000000
# 4      A227_neg_sur_v_4      5     A227            11   0.000  0.000000
# ...                 ...    ...      ...           ...     ...       ...
# 71403      A303_sad_v_4     82     A303             6   0.200  0.018109
# 71404      A303_sad_v_4     85     A303             6   0.126  0.088531
# 71405      A303_sad_v_4     87     A303             6   0.130  0.090543
# 71406      A303_sad_v_4     90     A303             6   0.312  0.211268
# 71407      A303_sad_v_4     91     A303             6   0.312  0.211268
#
#          AU04_r    AU05_r    AU06_r  AU07_r  ...    AU10_r    AU12_r  \
# 0      0.000000  0.000000  0.000000   0.000  ...  0.000000  0.000000
# 1      0.000000  0.077135  0.000000   0.000  ...  0.000000  0.000000
# 2      0.000000  0.129477  0.000000   0.000  ...  0.000000  0.000000
# 3      0.000000  0.165289  0.000000   0.010  ...  0.000000  0.000000
# 4      0.000000  0.099174  0.000000   0.010  ...  0.000000  0.000000
# ...         ...       ...       ...     ...  ...       ...       ...
# 71403  0.114286  0.000000  0.196617   0.206  ...  0.430998  0.256818
# 71404  0.085714  0.002755  0.063425   0.028  ...  0.199575  0.113636
# 71405  0.104082  0.079890  0.038055   0.000  ...  0.178344  0.100000
# 71406  0.157143  0.173554  0.000000   0.000  ...  0.142251  0.086364
# 71407  0.157143  0.173554  0.000000   0.000  ...  0.142251  0.086364
#
#          AU14_r  AU15_r    AU17_r    AU20_r  AU23_r  AU25_r    AU26_r  AU45_r
# 0      0.000000     0.0  0.000000  0.088643   0.000   0.144  0.614610     0.0
# 1      0.000000     0.0  0.000000  0.063712   0.012   0.164  0.526448     0.0
# 2      0.000000     0.0  0.000000  0.077562   0.020   0.186  0.483627     0.0
# 3      0.000000     0.0  0.000000  0.099723   0.018   0.214  0.450882     0.0
# 4      0.000000     0.0  0.000000  0.110803   0.018   0.232  0.471033     0.0
# ...         ...     ...       ...       ...     ...     ...       ...     ...
# 71403  0.089888     0.0  0.228866  0.000000   0.016   0.000  0.226700     0.0
# 71404  0.069663     0.0  0.152577  0.000000   0.000   0.000  0.115869     0.0
# 71405  0.078652     0.0  0.138144  0.000000   0.000   0.000  0.118388     0.0
# 71406  0.256180     0.0  0.309278  0.000000   0.000   0.000  0.292191     0.0
# 71407  0.256180     0.0  0.309278  0.000000   0.000   0.000  0.292191     0.0
#
# [71408 rows x 21 columns]

# %%
filenames = []
i = 0
for filename, series in df.groupby('filename'):
    filenames.append(filename)
    df_tmp = df[df['filename'] == filename] 
    
    x = df_tmp['frame'] 
    y = df_tmp['AU04_r']
    plt.plot(x, y)
    
    i += 1
    if i > 20:
        break
plt.show()

# %%
x = df1['frame'] 
y = df1['AU01_r']

# %%
x
# Out:
# 12009      1
# 12010      2
# 12011      3
# 12012      4
# 12013      5
#         ...
# 12275    267
# 12276    268
# 12277    269
# 12278    270
# 12279    271
# Name: frame, Length: 271, dtype: int64

# %%
plt.plot(x, y)
