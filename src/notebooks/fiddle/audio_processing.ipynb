# %%
import os
import time

import numpy as np
import pandas as pd

import audb
import audiofile
import opensmile

import matplotlib.pyplot as plt

# %%
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.GeMAPSv01b,
    feature_level=opensmile.FeatureLevel.LowLevelDescriptors,
)

# %%
df = smile.process_file('../example_videos/A220_ang_p_4.mov')

# %%
df.columns
# Out:
# Index(['Loudness_sma3', 'alphaRatio_sma3', 'hammarbergIndex_sma3',
#        'slope0-500_sma3', 'slope500-1500_sma3', 'F0semitoneFrom27.5Hz_sma3nz',
#        'jitterLocal_sma3nz', 'shimmerLocaldB_sma3nz', 'HNRdBACF_sma3nz',
#        'logRelF0-H1-H2_sma3nz', 'logRelF0-H1-A3_sma3nz', 'F1frequency_sma3nz',
#        'F1bandwidth_sma3nz', 'F1amplitudeLogRelF0_sma3nz',
#        'F2frequency_sma3nz', 'F2amplitudeLogRelF0_sma3nz',
#        'F3frequency_sma3nz', 'F3amplitudeLogRelF0_sma3nz'],
#       dtype='object')

# %%
df
# Out:
#                                                                                   F0final_sma  \
# file                               start                  end
# ../example_videos/A220_ang_p_4.mov 0 days 00:00:00        0 days 00:00:00.060000          0.0
#                                    0 days 00:00:00.010000 0 days 00:00:00.070000          0.0
#                                    0 days 00:00:00.020000 0 days 00:00:00.080000          0.0
#                                    0 days 00:00:00.030000 0 days 00:00:00.090000          0.0
#                                    0 days 00:00:00.040000 0 days 00:00:00.100000          0.0
# ...                                                                                       ...
#                                    0 days 00:00:09.010000 0 days 00:00:09.070000          0.0
#                                    0 days 00:00:09.020000 0 days 00:00:09.080000          0.0
# ...

# %%
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.eGeMAPSv02,
    feature_level=opensmile.FeatureLevel.LowLevelDescriptors,
)
df = smile.process_file('../example_videos/A220_ang_p_4.mov')

# %%
df.columns
# Out:
# Index(['Loudness_sma3', 'alphaRatio_sma3', 'hammarbergIndex_sma3',
#        'slope0-500_sma3', 'slope500-1500_sma3', 'spectralFlux_sma3',
#        'mfcc1_sma3', 'mfcc2_sma3', 'mfcc3_sma3', 'mfcc4_sma3',
#        'F0semitoneFrom27.5Hz_sma3nz', 'jitterLocal_sma3nz',
#        'shimmerLocaldB_sma3nz', 'HNRdBACF_sma3nz', 'logRelF0-H1-H2_sma3nz',
#        'logRelF0-H1-A3_sma3nz', 'F1frequency_sma3nz', 'F1bandwidth_sma3nz',
#        'F1amplitudeLogRelF0_sma3nz', 'F2frequency_sma3nz',
#        'F2bandwidth_sma3nz', 'F2amplitudeLogRelF0_sma3nz',
#        'F3frequency_sma3nz', 'F3bandwidth_sma3nz',
#        'F3amplitudeLogRelF0_sma3nz'],
#       dtype='object')

# %%
df
# Out:
#                                                                                   Loudness_sma3  \
# file                               start                  end
# ../example_videos/A220_ang_p_4.mov 0 days 00:00:00        0 days 00:00:00.020000       0.094180
#                                    0 days 00:00:00.010000 0 days 00:00:00.030000       0.091902
#                                    0 days 00:00:00.020000 0 days 00:00:00.040000       0.087588
#                                    0 days 00:00:00.030000 0 days 00:00:00.050000       0.083225
#                                    0 days 00:00:00.040000 0 days 00:00:00.060000       0.079640
# ...                                                                                         ...
#                                    0 days 00:00:09.010000 0 days 00:00:09.030000       0.113995
#                                    0 days 00:00:09.020000 0 days 00:00:09.040000       0.110953
# ...

# %%
plt.plot(df["F0final_sma"].to_numpy())

# %%
plt.plot(df["audspecRasta_lengthL1norm_sma"].to_numpy())

# %%
plt.plot(df["pcm_RMSenergy_sma"].to_numpy())

# %%
plt.plot(df["logHNR_sma"].to_numpy())

# %%
plt.plot(df["voicingFinalUnclipped_sma"].to_numpy())

# %%
plt.plot(df["mfcc_sma[5]"].to_numpy())

# %%
gemaps = ['Loudness_sma3', 'alphaRatio_sma3', 'hammarbergIndex_sma3',
       'slope0-500_sma3', 'slope500-1500_sma3', 'F0semitoneFrom27.5Hz_sma3nz',
       'jitterLocal_sma3nz', 'shimmerLocaldB_sma3nz', 'HNRdBACF_sma3nz',
       'logRelF0-H1-H2_sma3nz', 'logRelF0-H1-A3_sma3nz', 'F1frequency_sma3nz',
       'F1bandwidth_sma3nz', 'F1amplitudeLogRelF0_sma3nz',
       'F2frequency_sma3nz', 'F2amplitudeLogRelF0_sma3nz',
       'F3frequency_sma3nz', 'F3amplitudeLogRelF0_sma3nz']

# %%
for i in gemaps:
    print(i)
# Out:
# Loudness_sma3
# alphaRatio_sma3
# hammarbergIndex_sma3
# slope0-500_sma3
# slope500-1500_sma3
# F0semitoneFrom27.5Hz_sma3nz
# jitterLocal_sma3nz
# shimmerLocaldB_sma3nz
# HNRdBACF_sma3nz
# logRelF0-H1-H2_sma3nz
# logRelF0-H1-A3_sma3nz
# F1frequency_sma3nz
# F1bandwidth_sma3nz
# F1amplitudeLogRelF0_sma3nz
# F2frequency_sma3nz
# F2amplitudeLogRelF0_sma3nz
# F3frequency_sma3nz
# F3amplitudeLogRelF0_sma3nz

# %%
egemaps = ['Loudness_sma3', 'alphaRatio_sma3', 'hammarbergIndex_sma3',
       'slope0-500_sma3', 'slope500-1500_sma3', 'spectralFlux_sma3',
       'mfcc1_sma3', 'mfcc2_sma3', 'mfcc3_sma3', 'mfcc4_sma3',
       'F0semitoneFrom27.5Hz_sma3nz', 'jitterLocal_sma3nz',
       'shimmerLocaldB_sma3nz', 'HNRdBACF_sma3nz', 'logRelF0-H1-H2_sma3nz',
       'logRelF0-H1-A3_sma3nz', 'F1frequency_sma3nz', 'F1bandwidth_sma3nz',
       'F1amplitudeLogRelF0_sma3nz', 'F2frequency_sma3nz',
       'F2bandwidth_sma3nz', 'F2amplitudeLogRelF0_sma3nz',
       'F3frequency_sma3nz', 'F3bandwidth_sma3nz',
       'F3amplitudeLogRelF0_sma3nz']

# %%
for i in egemaps:
    if i in gemaps:
        pass
        #print(i + " is in gemaps")
    else:
        print(i + " is not in gemaps")
# Out:
# spectralFlux_sma3 is not in gemaps
# mfcc1_sma3 is not in gemaps
# mfcc2_sma3 is not in gemaps
# mfcc3_sma3 is not in gemaps
# mfcc4_sma3 is not in gemaps
# F2bandwidth_sma3nz is not in gemaps
# F3bandwidth_sma3nz is not in gemaps

# %%
path = "../audio_files/egemaps_norm_A01amu111.csv"
df = pd.read_csv(path, delimiter=";")

# %%
df
# Out:
#    frameIndex  frameTime  F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0           0        0.0                           38.28683
#
#    F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                0.174699
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                    35.24582
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                    40.81793
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                    43.58985
#
#    F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                  8.344032
#
#    F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 0                                     119.4943
#
#    F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  ...  \
# 0                                       65.28829  ...
#
#    slopeUV0-500_sma3nz_amean  slopeUV500-1500_sma3nz_amean  \
# 0                   0.042719                     -0.011299
#
# ...

# %%
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.eGeMAPSv02,
    feature_level=opensmile.FeatureLevel.Functionals,
)
df = smile.process_file('../example_videos/A220_ang_p_4.mov')

# %%
df
# Out:
#                                                                   F0semitoneFrom27.5Hz_sma3nz_amean  \
# file                               start  end
# ../example_videos/A220_ang_p_4.mov 0 days 0 days 00:00:09.100000                          41.112404
#
#                                                                   F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# file                               start  end
# ../example_videos/A220_ang_p_4.mov 0 days 0 days 00:00:09.100000                                0.059631
#
#                                                                   F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# file                               start  end
# ../example_videos/A220_ang_p_4.mov 0 days 0 days 00:00:09.100000                                    39.93034
#
#                                                                   F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# file                               start  end
# ...

# %%
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.GeMAPSv01b,
    feature_level=opensmile.FeatureLevel.Functionals,
)
gemaps = smile.process_file('../example_videos/A220_ang_p_4.mov')

smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.eGeMAPSv02,
    feature_level=opensmile.FeatureLevel.Functionals,
)
egemaps = smile.process_file('../example_videos/A220_ang_p_4.mov')

# %%
for i in gemaps.columns:
    if i not in egemaps:
        print(i)
